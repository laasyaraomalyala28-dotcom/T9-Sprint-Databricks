# %%
# %sql
-- CREATE UNITY CATALOG
CREATE CATALOG IF NOT EXISTS retail_lakehouse;

# %%
# %sql
-- CREATE SCHEMAS

CREATE SCHEMA IF NOT EXISTS retail_lakehouse.bronze;

CREATE SCHEMA IF NOT EXISTS retail_lakehouse.silver;

CREATE SCHEMA IF NOT EXISTS retail_lakehouse.gold;

# %%
# %sql
-- VERIFY CATALOGS AND SCHEMAS

SHOW CATALOGS;

SHOW SCHEMAS IN retail_lakehouse;

# %%
# %sql
-- OPTIONAL CLEANUP SECTION
-- (Run only if restarting project)

DROP TABLE IF EXISTS retail_lakehouse.gold.fact_sales;

DROP TABLE IF EXISTS retail_lakehouse.gold.dim_customer;

DROP TABLE IF EXISTS retail_lakehouse.gold.dim_product;

DROP TABLE IF EXISTS retail_lakehouse.gold.dim_store;

DROP TABLE IF EXISTS retail_lakehouse.silver.sales;

DROP TABLE IF EXISTS retail_lakehouse.silver.customers;

DROP TABLE IF EXISTS retail_lakehouse.silver.products;

DROP TABLE IF EXISTS retail_lakehouse.silver.stores;

DROP TABLE IF EXISTS retail_lakehouse.bronze.sales;

DROP TABLE IF EXISTS retail_lakehouse.bronze.customers;

DROP TABLE IF EXISTS retail_lakehouse.bronze.products;

DROP TABLE IF EXISTS retail_lakehouse.bronze.stores;
